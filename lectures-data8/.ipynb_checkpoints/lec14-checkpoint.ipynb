# %%
from datascience import *
# %matplotlib inline
path_data = '../../../assets/data/'
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import numpy as np
import warnings
warnings.simplefilter(action='ignore')

# %% [markdown]
# ## For statements

# %%
for pet in make_array('cat', 'dog', 'rabbit'):
    print('I love my ' + pet)
# Out:
# I love my cat
# I love my dog
# I love my rabbit

# %%
temporary = make_array('cat', 'dog', 'rabbit')

pet = temporary.item(0)
print('I love my ' + pet)

pet = temporary.item(1)
print('I love my ' + pet)

pet = temporary.item(2)
print('I love my ' + pet)
# Out:
# I love my cat
# I love my dog
# I love my rabbit

# %%
for i in np.arange(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in np.arange(5):
    print('Go Bears')
# Out:
# Go Bears
# Go Bears
# Go Bears
# Go Bears
# Go Bears

# %%
s = make_array(2, 3)
np.append(s, 4)
s
# Out:
# array([2, 3])

# %%
s + 3
s
# Out:
# array([2, 3])

# %%
s = np.append(s, 4)
s
# Out:
# array([2, 3, 4])

# %%
result = make_array(2, 3, 4)
for i in np.arange(5):
    result = np.append(result, 10 * i)
result
# Out:
# array([ 2,  3,  4,  0, 10, 20, 30, 40])

# %% [markdown]
# ## Simulating heads in 100 coin tosses

# %%
coin = make_array('heads', 'tails')

# %%
sum(np.random.choice(coin, 100) == 'heads')
# Out:
# 59

# %%
# Simulate one outcome

def num_heads(n):
    return sum(np.random.choice(coin, n) == 'heads')

# %%
# Decide how many times you want to repeat the experiment

repetitions = 10000

# %%
# Simulate that many outcomes

outcomes = make_array()

for i in np.arange(repetitions):
    outcomes = np.append(outcomes, num_heads(100))

# %%
heads = Table().with_column('Heads', outcomes)
heads.hist(bins = np.arange(29.5, 70.6))

# %% [markdown]
# # Lecture 14 #

# %% [markdown]
# Box contains cards labeled R, B, and G. I **draw two cards at random without replacement**.

# %% [markdown]
# ### Chance of two events both occurring ###
# What is the chance that I get G followed by B?
#
# (both "get G first" and "get B second")

# %%
# P ('G first' and 'B second') = P(G) * P(B|G) = 1/3 * 1/2 = 1/6

# %% [markdown]
# ### Chance of an event that can happen in multiple ways ###
# What is the chance that one of the ticket is G and the other is B?

# %%
# P ('G and B' or 'B and G') = P ('G and B') + P ('B and G') = 1/6 + 1/6 = 1/3

# %% [markdown]
# ### Challenge Question 1 ###
#
# **Without calculation:** What is the chance that the second card drawn is B?

# %%
# without calculation: P( second is B ) = 1/3, equal distribution|
# with calculation: P('B second') = P('R and B') + P('G and B') = 1/6 + 1/6 = 1/3

# %% [markdown]
# # Challenge Question 2 ###
#
# I have a deck of 52 cards. It contains four aces, one of which is the ace of hearts.
#
# I shuffle the deck and deal 13 cards.
#
# **Without calculation:** What is the chance that the 12th card is the ace of hearts? \n

# %%
# P('12th card ace of hearts') = 1 / 12 # nothing special about 12th position

# %% [markdown]
# ### Chance of At Least One Success in Independently Repeated Success/Failure Trials ###

# %%
# Chance of no sixes in 4 rolls of a die

prob_no_sixes_in_four_rolls = (5/6)**4
prob_no_sixes_in_four_rolls
# Out:
# 0.4822530864197532

# %%
# Chance of at least one six in 4 rolls of a die
1 - prob_no_sixes_in_four_rolls
# Out:
# 0.5177469135802468

# %%
# Chance of at least one six in n rolls of a die

rolls = np.arange(1, 51, 1)
results = Table().with_columns(
    'Rolls', rolls,
    'Chance of at least one 6', 1 - (5/6)**rolls
)
results
# Out:
# Rolls | Chance of at least one 6
# 1     | 0.166667
# 2     | 0.305556
# 3     | 0.421296
# 4     | 0.517747
# 5     | 0.598122
# 6     | 0.665102
# 7     | 0.720918
# 8     | 0.767432
# 9     | 0.806193
# 10    | 0.838494
# ... (40 rows omitted)

# %%
results.scatter('Rolls')

# %% [markdown]
# ### The Monty Hall Problem ###

# %%
goats = make_array('first goat', 'second goat')

# %%
def other_goat(x):
    if x == 'first goat':
        return 'second goat'
    elif x == 'second goat':
        return 'first goat'

# %%
[other_goat('first goat'), other_goat('second goat')]
# Out:
# ['second goat', 'first goat']

# %%
hidden_behind_doors = np.append(goats, 'car')
hidden_behind_doors
# Out:
# array(['first goat', 'second goat', 'car'],
#       dtype='<U11')

# %%
def monty_hall_game():
    """Return 
    [contestant's guess, what Monty reveals, what remains behind the other door]"""
    
    contestant_guess = np.random.choice(hidden_behind_doors)
    
    if contestant_guess == 'first goat':
        return [contestant_guess, 'second goat', 'car']
    
    if contestant_guess == 'second goat':
        return [contestant_guess, 'first goat', 'car']
    
    if contestant_guess == 'car':
        revealed = np.random.choice(goats)
        return [contestant_guess, revealed, other_goat(revealed)]

# %%
monty_hall_game()
# Out:
# ['second goat', 'first goat', 'car']

# %%
games = Table(['Guess', 'Revealed', 'Remaining'])

for i in np.arange(10000):
    games.append(monty_hall_game())

# %%
games.show(3)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Guess</th> <th>Revealed</th> <th>Remaining</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>car       </td> <td>second goat</td> <td>first goat </td>
#         </tr>
#         <tr>
#             <td>first goat</td> <td>second goat</td> <td>car        </td>
#         </tr>
#         <tr>
#             <td>car       </td> <td>first goat </td> <td>second goat</td>
#         </tr>
#     </tbody>
# </table>
# <p>... (9997 rows omitted)</p>

# %%
original_choice = games.group('Guess')
original_choice
# Out:
# Guess       | count
# car         | 3374
# first goat  | 3353
# second goat | 3273

# %%
remaining_door = games.group('Remaining')
remaining_door
# Out:
# Remaining   | count
# car         | 6626
# first goat  | 1664
# second goat | 1710

# %%
joined = original_choice.join('Guess', remaining_door, 'Remaining')
combined = joined.relabeled(0, 'Item').relabeled(1, 'Original Door').relabeled(2, 'Remaining Door')
combined
# Out:
# Item        | Original Door | Remaining Door
# car         | 3374          | 6626
# first goat  | 3353          | 1664
# second goat | 3273          | 1710

# %%
combined.barh(0)
