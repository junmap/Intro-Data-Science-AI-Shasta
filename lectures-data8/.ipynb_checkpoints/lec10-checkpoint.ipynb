# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
import warnings
warnings.simplefilter(action='ignore')

# %% [markdown]
# ## Lecture 10 ##

# %% [markdown]
# ## Prediction ##

# %%
families = Table.read_table('family_heights.csv')
families
# Out:
# family | father | mother | child | children | order | sex
# 1      | 78.5   | 67     | 73.2  | 4        | 1     | male
# 1      | 78.5   | 67     | 69.2  | 4        | 2     | female
# 1      | 78.5   | 67     | 69    | 4        | 3     | female
# 1      | 78.5   | 67     | 69    | 4        | 4     | female
# 2      | 75.5   | 66.5   | 73.5  | 4        | 1     | male
# 2      | 75.5   | 66.5   | 72.5  | 4        | 2     | male
# 2      | 75.5   | 66.5   | 65.5  | 4        | 3     | female
# 2      | 75.5   | 66.5   | 65.5  | 4        | 4     | female
# 3      | 75     | 64     | 71    | 2        | 1     | male
# 3      | 75     | 64     | 68    | 2        | 2     | female
# ... (924 rows omitted)

# %%
parent_avgs = (families.column('father') + families.column('mother'))/2

# %%
heights = Table().with_columns(
    'Parent Average', parent_avgs,
    'Child', families.column('child'),
    'Sex', families.column('sex')
)
heights
# Out:
# Parent Average | Child | Sex
# 72.75          | 73.2  | male
# 72.75          | 69.2  | female
# 72.75          | 69    | female
# 72.75          | 69    | female
# 71             | 73.5  | male
# 71             | 72.5  | male
# 71             | 65.5  | female
# 71             | 65.5  | female
# 69.5           | 71    | male
# 69.5           | 68    | female
# ... (924 rows omitted)

# %%
heights.scatter('Parent Average', 'Child')

# %%
heights.scatter('Parent Average', 'Child')
plots.plot([67.5, 67.5], [50, 85], color='red', lw=2)
plots.plot([68.5, 68.5], [50, 85], color='red', lw=2);

# %%
nearby = heights.where('Parent Average', are.between(67.5, 68.5))
nearby_mean = np.average(nearby.column('Child'))
nearby_mean
# Out:
# 67.620000000000005

# %%
heights.scatter('Parent Average', 'Child')
plots.plot([67.5, 67.5], [50, 85], color='red', lw=2)
plots.plot([68.5, 68.5], [50, 85], color='red', lw=2)
plots.scatter(68, nearby_mean, color='red', s=50); # s=50 is point size of the point (68,nearby_mean)

# %%
def predict(h):
    nearby = heights.where('Parent Average', are.between(h - 1/2, h + 1/2))
    return np.average(nearby.column('Child'))

# %%
predict(68)
# Out:
# 67.620000000000005

# %%
predict(70)
# Out:
# 68.561904761904756

# %%
predict(73)
# Out:
# 70.099999999999994

# %%
predicted_heights = heights.apply(predict, 'Parent Average')

# %%
heights = heights.with_column('Prediction', predicted_heights)
heights
# Out:
# Parent Average | Child | Sex    | Prediction
# 72.75          | 73.2  | male   | 70.1
# 72.75          | 69.2  | female | 70.1
# 72.75          | 69    | female | 70.1
# 72.75          | 69    | female | 70.1
# 71             | 73.5  | male   | 70.4158
# 71             | 72.5  | male   | 70.4158
# 71             | 65.5  | female | 70.4158
# 71             | 65.5  | female | 70.4158
# 69.5           | 71    | male   | 68.5025
# 69.5           | 68    | female | 68.5025
# ... (924 rows omitted)

# %%
heights.select('Parent Average', 'Child', 'Prediction').scatter('Parent Average') # 'Child' and 'Predicrtion' are both ploted on the y-axis
# heights.select('Parent Average', 'Child', 'Prediction').scatter('Parent Average','Child') # only plot "Child" without "Prediction' on the y-axis

# %% [markdown]
# ## Prediction Accuracy ##

# %%
def difference(x, y):
    return x - y

# %%
pred_errs = heights.apply(difference, 'Prediction', 'Child')
heights = heights.with_column('errors',pred_errs)
heights
# Out:
# Parent Average | Child | Sex    | Prediction | errors
# 72.75          | 73.2  | male   | 70.1       | -3.1
# 72.75          | 69.2  | female | 70.1       | 0.9
# 72.75          | 69    | female | 70.1       | 1.1
# 72.75          | 69    | female | 70.1       | 1.1
# 71             | 73.5  | male   | 70.4158    | -3.08421
# 71             | 72.5  | male   | 70.4158    | -2.08421
# 71             | 65.5  | female | 70.4158    | 4.91579
# 71             | 65.5  | female | 70.4158    | 4.91579
# 69.5           | 71    | male   | 68.5025    | -2.4975
# 69.5           | 68    | female | 68.5025    | 0.5025
# ... (924 rows omitted)

# %%
heights.hist('errors')

# %%
heights.hist('errors', group='Sex') # errors are biased by sex group

# %% [markdown]
# # Discussion Question

# %%
def predict_smarter(h, s):
    nearby = heights.where('Parent Average', are.between(h - 1/2, h + 1/2))
    nearby_same_sex = nearby.where('Sex', s)
    return np.average(nearby_same_sex.column('Child'))

# %%
predict_smarter(68, 'female')
# Out:
# 64.983516483516482

# %%
predict_smarter(68, 'male')
# Out:
# 70.172340425531914

# %%
smarter_predicted_heights = heights.apply(predict_smarter, 'Parent Average', 'Sex')
heights = heights.with_column('Smarter Prediction', smarter_predicted_heights)

# %%
smarter_pred_errs = heights.apply(difference, 'Child', 'Smarter Prediction')
heights = heights.with_column('Smarter Errors', smarter_pred_errs)

# %%
heights.hist('Smarter Errors', group='Sex') # close to bell shape

# %% [markdown]
# ## Grouping by One Column ##

# %%
cones = Table.read_table('cones.csv').drop('Color')
cones
# Out:
# Flavor     | Price
# strawberry | 3.55
# chocolate  | 4.75
# chocolate  | 5.25
# strawberry | 5.25
# chocolate  | 5.25
# bubblegum  | 4.75

# %%
cones.group('Flavor')
# Out:
# Flavor     | count
# bubblegum  | 1
# chocolate  | 3
# strawberry | 2

# %%
cones.group('Flavor', np.average)
# Out:
# Flavor     | Price average
# bubblegum  | 4.75
# chocolate  | 5.08333
# strawberry | 4.4

# %%
cones.group('Flavor', np.min)
# Out:
# Flavor     | Price min
# bubblegum  | 4.75
# chocolate  | 4.75
# strawberry | 3.55

# %% [markdown]
# ## Grouping By One Column: Welcome Survey ##

# %%
survey = Table.read_table('welcome_survey_sp22.csv')
survey.show(3)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Year</th> <th>Extroversion</th> <th>Number of textees</th> <th>Hours of sleep</th> <th>Handedness</th> <th>Pant leg</th> <th>Sleep position</th> <th>Pets</th> <th>Piercings</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Second</td> <td>5           </td> <td>5                </td> <td>8             </td> <td>Left-handed </td> <td>Left leg in first </td> <td>On your left side</td> <td>Ants                          </td> <td>0        </td>
#         </tr>
#         <tr>
#             <td>Fourth</td> <td>2           </td> <td>3                </td> <td>7             </td> <td>Right-handed</td> <td>Left leg in first </td> <td>On your left side</td> <td>Beetles, Centipedes, Scorpions</td> <td>0        </td>
#         </tr>
#         <tr>
#             <td>First </td> <td>3           </td> <td>4                </td> <td>8             </td> <td>Right-handed</td> <td>Right leg in first</td> <td>On your back     </td> <td>Bird                          </td> <td>0        </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (1340 rows omitted)</p>

# %%
survey.hist('Extroversion')

# %%
by_extra = survey.group('Extroversion', np.average)
by_extra
# Out:
# Extroversion | Year average | Number of textees average | Hours of sleep average | Handedness average | Pant leg average | Sleep position average | Pets average | Piercings average
# 1            |              | 2.08696                   | 7.32609                |                    |                  |                        |              | 0.478261
# 2            |              | 3.21951                   | 7.30488                |                    |                  |                        |              | 0.95122
# 3            |              | 4.71338                   | 7.17516                |                    |                  |                        |              | 1.57962
# 4            |              | 4.96653                   | 7.25941                |                    |                  |                        |              | 1.7113
# 5            |              | 5.39796                   | 7.06888                |                    |                  |                        |              | 1.45408
# 6            |              | 5.8141                    | 7.125                  |                    |                  |                        |              | 1.83974
# 7            |              | 8.15721                   | 7.04367                |                    |                  |                        |              | 2.06987
# 8            |              | 7.95475                   | 7.07692                |                    |                  |                        |              | 2
# 9            |              | 10.7778                   | 7.15741                |                    |                  |                        |              | 2.88889
# 10           |              | 13.037                    | 7.16667                |                    |                  |                        |              | 1.92593

# %%
by_extra.plot('Extroversion', 'Number of textees average')

# %%
survey.group("Year")
# Out:
# Year                                                         | count
# Fifth or above                                               | 18
# First                                                        | 577
# First year In Master's Degree                                | 1
# Fourth                                                       | 96
# I dont understand this question, I'm a first year but se ... | 1
# Junior Transfer                                              | 1
# Not an undergrad                                             | 3
# Second                                                       | 419
# Third                                                        | 227

# %%
(survey
 .select("Year", "Hours of sleep")
 .group(0, np.average) # group according "Year", and computer average hours of sleep
 .take(1, 7, 8, 3)) # take rows
# Out:
# Year   | Hours of sleep average
# First  | 7.19757
# Second | 7.1778
# Third  | 6.96696
# Fourth | 6.92188

# %% [markdown]
# ## Lists

# %%
[1, 5, 'hello', 5.0]
# Out:
# [1, 5, 'hello', 5.0]

# %%
[1, 5, 'hello', 5.0, make_array(1,2,3)]
# Out:
# [1, 5, 'hello', 5.0, array([1, 2, 3])]

# %% [markdown]
# ## Grouping by Two Columns ##

# %% [markdown]
# ![Do right-handed people tend to sleep on their left side and left-handed people sleep on their right?](handed.png)

# %%
# answer to above questions is Not really, it is random from the output
survey.group(['Handedness', 'Sleep position']).show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Handedness</th> <th>Sleep position</th> <th>count</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Both        </td> <td>On your back      </td> <td>2    </td>
#         </tr>
#         <tr>
#             <td>Both        </td> <td>On your left side </td> <td>1    </td>
#         </tr>
#         <tr>
#             <td>Both        </td> <td>On your right side</td> <td>3    </td>
#         </tr>
#         <tr>
#             <td>Both        </td> <td>On your stomach   </td> <td>3    </td>
#         </tr>
#         <tr>
#             <td>Left-handed </td> <td>On your back      </td> <td>15   </td>
#         </tr>
#         <tr>
#             <td>Left-handed </td> <td>On your left side </td> <td>30   </td>
#         </tr>
#         <tr>
#             <td>Left-handed </td> <td>On your right side</td> <td>31   </td>
#         </tr>
#         <tr>
#             <td>Left-handed </td> <td>On your stomach   </td> <td>17   </td>
#         </tr>
#         <tr>
#             <td>Right-handed</td> <td>On your back      </td> <td>299  </td>
#         </tr>
#         <tr>
#             <td>Right-handed</td> <td>On your left side </td> <td>315  </td>
#         </tr>
#         <tr>
#             <td>Right-handed</td> <td>On your right side</td> <td>451  </td>
#         </tr>
#         <tr>
#             <td>Right-handed</td> <td>On your stomach   </td> <td>176  </td>
#         </tr>
#     </tbody>
# </table>
