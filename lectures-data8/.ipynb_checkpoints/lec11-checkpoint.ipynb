# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
import warnings
warnings.simplefilter(action='ignore')

# %% [markdown]
# # Lecture 11 #

# %% [markdown]
# ### Rows from lists

# %%
Table().with_columns('Numbers', [1, 2, 3])
# Out:
# Numbers
# 1
# 2
# 3

# %%
drinks = Table(['Drink', 'Cafe', 'Price'])
drinks
# Out:
# Drink | Cafe | Price

# %%
drinks = drinks.with_rows([
    ['Milk Tea', 'Asha', 5.5],
    ['Espresso', 'Strada',  1.75],
    ['Latte',    'Strada',  3.25],
    ['Espresso', "FSM",   2]
])
drinks
# Out:
# Drink    | Cafe   | Price
# Milk Tea | Asha   | 5.5
# Espresso | Strada | 1.75
# Latte    | Strada | 3.25
# Espresso | FSM    | 2

# %% [markdown]
# ## Review: Group by one column

# %%
survey = Table.read_table('welcome_survey_sp22.csv')
survey.show(3)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Year</th> <th>Extroversion</th> <th>Number of textees</th> <th>Hours of sleep</th> <th>Handedness</th> <th>Pant leg</th> <th>Sleep position</th> <th>Pets</th> <th>Piercings</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Second</td> <td>5           </td> <td>5                </td> <td>8             </td> <td>Left-handed </td> <td>Left leg in first </td> <td>On your left side</td> <td>Ants                          </td> <td>0        </td>
#         </tr>
#         <tr>
#             <td>Fourth</td> <td>2           </td> <td>3                </td> <td>7             </td> <td>Right-handed</td> <td>Left leg in first </td> <td>On your left side</td> <td>Beetles, Centipedes, Scorpions</td> <td>0        </td>
#         </tr>
#         <tr>
# ...

# %%
survey.group("Year")
# Out:
# Year                                                         | count
# Fifth or above                                               | 18
# First                                                        | 577
# First year In Master's Degree                                | 1
# Fourth                                                       | 96
# I dont understand this question, I'm a first year but se ... | 1
# Junior Transfer                                              | 1
# Not an undergrad                                             | 3
# Second                                                       | 419
# Third                                                        | 227

# %%
(survey
 .select("Year", "Hours of sleep")
 .group(0, np.average)
 .take(1, 7, 8, 3))
# Out:
# Year   | Hours of sleep average
# First  | 7.19757
# Second | 7.1778
# Third  | 6.96696
# Fourth | 6.92188

# %% [markdown]
# ## Cross-classification: grouping by two columns

# %%
survey.group(['Handedness', 'Sleep position']).show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Handedness</th> <th>Sleep position</th> <th>count</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Both        </td> <td>On your back      </td> <td>2    </td>
#         </tr>
#         <tr>
#             <td>Both        </td> <td>On your left side </td> <td>1    </td>
#         </tr>
#         <tr>
#             <td>Both        </td> <td>On your right side</td> <td>3    </td>
#         </tr>
#         <tr>
#             <td>Both        </td> <td>On your stomach   </td> <td>3    </td>
#         </tr>
#         <tr>
#             <td>Left-handed </td> <td>On your back      </td> <td>15   </td>
#         </tr>
#         <tr>
#             <td>Left-handed </td> <td>On your left side </td> <td>30   </td>
#         </tr>
#         <tr>
#             <td>Left-handed </td> <td>On your right side</td> <td>31   </td>
#         </tr>
#         <tr>
# ...

# %%
survey.group(['Handedness', 'Sleep position'],
             np.average).show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Handedness</th> <th>Sleep position</th> <th>Year average</th> <th>Extroversion average</th> <th>Number of textees average</th> <th>Hours of sleep average</th> <th>Pant leg average</th> <th>Pets average</th> <th>Piercings average</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Both        </td> <td>On your back      </td> <td>            </td> <td>7                   </td> <td>6                        </td> <td>5                     </td> <td>                </td> <td>            </td> <td>4.5              </td>
#         </tr>
#         <tr>
#             <td>Both        </td> <td>On your left side </td> <td>            </td> <td>7                   </td> <td>10                       </td> <td>6                     </td> <td>                </td> <td>            </td> <td>0                </td>
#         </tr>
#         <tr>
# ...

# %% [markdown]
# ## Pivot Tables

# %%
survey.group('Handedness')
# Out:
# Handedness   | count
# Both         | 9
# Left-handed  | 93
# Right-handed | 1241

# %%
survey.pivot('Sleep position', 'Handedness')
# Out:
# Handedness   | On your back | On your left side | On your right side | On your stomach
# Both         | 2            | 1                 | 3                  | 3
# Left-handed  | 15           | 30                | 31                 | 17
# Right-handed | 299          | 315               | 451                | 176

# %%
survey.pivot('Sleep position', 
             'Handedness', 
             values='Hours of sleep', 
             collect=np.average)
# Out:
# Handedness   | On your back | On your left side | On your right side | On your stomach
# Both         | 5            | 6                 | 8.16667            | 8.33333
# Left-handed  | 7.06667      | 6.96667           | 7.04839            | 7.5
# Right-handed | 7.11538      | 7.11905           | 7.11863            | 7.25284

# %% [markdown]
# ## Discussion Questions ##

# %%
# From the CORGIS Dataset Project
# By Austin Cory Bart acbart@vt.edu
# Version 2.0.0, created 3/22/2016
# https://corgis-edu.github.io/corgis/csv/skyscrapers/

sky = Table.read_table('skyscrapers.csv')
sky = (sky.with_column('age', 2027 - sky.column('completed'))
          .drop('completed'))
sky.show(3)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>name</th> <th>material</th> <th>city</th> <th>height</th> <th>age</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>One World Trade Center</td> <td>mixed/composite</td> <td>New York City</td> <td>541.3 </td> <td>13  </td>
#         </tr>
#         <tr>
#             <td>Willis Tower          </td> <td>steel          </td> <td>Chicago      </td> <td>442.14</td> <td>53  </td>
#         </tr>
#         <tr>
#             <td>432 Park Avenue       </td> <td>concrete       </td> <td>New York City</td> <td>425.5 </td> <td>12  </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (1778 rows omitted)</p>

# %%
# 1. For each city, what’s the tallest building for each material?
sky_tallest = sky.group(['city', 'material'], max)
sky_tallest
# Out:
# city      | material        | name max                                | height max | age max
# Atlanta   | concrete        | Westin Peachtree Plaza                  | 264.25     | 51
# Atlanta   | mixed/composite | Two Alliance Center                     | 311.8      | 40
# Atlanta   | steel           | State of Georgia Building               | 169.47     | 130
# Austin    | concrete        | Windsor on the Lake                     | 208.15     | 43
# Austin    | steel           | University of Texas Tower               | 93.6       | 90
# Baltimore | concrete        | The John and Frances Angelos Law Center | 161.24     | 60
# Baltimore | steel           | Mercy Medical Center Inpatient Tower    | 155.15     | 116
# Boston    | concrete        | Harbor Towers II                        | 121.92     | 56
# Boston    | mixed/composite | Ellison Building                        | 139        | 35
# Boston    | steel           | Two International Place                 | 240.79     | 112
# ...

# %%
# 2. For each city, what’s the height difference between the tallest 
#    steel building and the tallest concrete building?
sky_p = sky.pivot('material', 'city', values='height', collect=max)
sky_p = sky_p.with_column('difference',abs(sky_p.column('steel')-sky_p.column('concrete')))
sky_p.sort('difference',True)
# Out:
# city              | concrete | mixed/composite | steel  | difference
# Sunny Isles Beach | 196      | 0               | 0      | 196
# Las Vegas         | 350.22   | 195.68          | 164.6  | 185.62
# Miami Beach       | 170.39   | 0               | 0      | 170.39
# Pittsburgh        | 89.3     | 172             | 256.34 | 167.04
# Los Angeles       | 145.7    | 118.26          | 310.29 | 164.59
# Philadelphia      | 157.89   | 296.73          | 288.04 | 130.15
# Boston            | 121.92   | 139             | 240.79 | 118.87
# Austin            | 208.15   | 0               | 93.6   | 114.55
# Seattle           | 138.69   | 284.38          | 235.31 | 96.62
# Atlanta           | 264.25   | 311.8           | 169.47 | 94.78
# ... (25 rows omitted)

# %% [markdown]
# Don't read ahead until you try the challenge questions yourself first!

# %%
sky.select('material', 'city', 'height').group(['city', 'material'], collect=max)
# Out:
# city      | material        | height max
# Atlanta   | concrete        | 264.25
# Atlanta   | mixed/composite | 311.8
# Atlanta   | steel           | 169.47
# Austin    | concrete        | 208.15
# Austin    | steel           | 93.6
# Baltimore | concrete        | 161.24
# Baltimore | steel           | 155.15
# Boston    | concrete        | 121.92
# Boston    | mixed/composite | 139
# Boston    | steel           | 240.79
# ... (81 rows omitted)

# %%
sky_p = sky.pivot('material', 'city', values='height', collect=max)
sky_p.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>city</th> <th>concrete</th> <th>mixed/composite</th> <th>steel</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Atlanta          </td> <td>264.25  </td> <td>311.8          </td> <td>169.47</td>
#         </tr>
#         <tr>
#             <td>Austin           </td> <td>208.15  </td> <td>0              </td> <td>93.6  </td>
#         </tr>
#         <tr>
#             <td>Baltimore        </td> <td>161.24  </td> <td>0              </td> <td>155.15</td>
#         </tr>
#         <tr>
#             <td>Boston           </td> <td>121.92  </td> <td>139            </td> <td>240.79</td>
#         </tr>
#         <tr>
#             <td>Charlotte        </td> <td>265.48  </td> <td>239.7          </td> <td>179.23</td>
#         </tr>
#         <tr>
#             <td>Chicago          </td> <td>423.22  </td> <td>306.94         </td> <td>442.14</td>
#         </tr>
#         <tr>
# ...

# %%
sky_p = sky_p.with_column(
    'difference', 
    abs(sky_p.column('steel') - sky_p.column('concrete'))
)
sky_p
# Out:
# city       | concrete | mixed/composite | steel  | difference
# Atlanta    | 264.25   | 311.8           | 169.47 | 94.78
# Austin     | 208.15   | 0               | 93.6   | 114.55
# Baltimore  | 161.24   | 0               | 155.15 | 6.09001
# Boston     | 121.92   | 139             | 240.79 | 118.87
# Charlotte  | 265.48   | 239.7           | 179.23 | 86.25
# Chicago    | 423.22   | 306.94          | 442.14 | 18.92
# Cincinnati | 125      | 202.69          | 175    | 50
# Cleveland  | 125      | 288.65          | 215.8  | 90.8
# Columbus   | 79.25    | 0               | 169.3  | 90.05
# Dallas     | 176.48   | 280.72          | 270.06 | 93.58
# ... (25 rows omitted)

# %%
sky_p.sort('difference', True)
# Out:
# city              | concrete | mixed/composite | steel  | difference
# Sunny Isles Beach | 196      | 0               | 0      | 196
# Las Vegas         | 350.22   | 195.68          | 164.6  | 185.62
# Miami Beach       | 170.39   | 0               | 0      | 170.39
# Pittsburgh        | 89.3     | 172             | 256.34 | 167.04
# Los Angeles       | 145.7    | 118.26          | 310.29 | 164.59
# Philadelphia      | 157.89   | 296.73          | 288.04 | 130.15
# Boston            | 121.92   | 139             | 240.79 | 118.87
# Austin            | 208.15   | 0               | 93.6   | 114.55
# Seattle           | 138.69   | 284.38          | 235.31 | 96.62
# Atlanta           | 264.25   | 311.8           | 169.47 | 94.78
# ... (25 rows omitted)

# %%
# 3. Generate a table of the names of the oldest buildings for each 
#    material for each city:

# Hint: You can use sort to find the name of the oldest building in the dataset
# sky_age = sky.sort('age', descending=True).column('name').item(0)
def first(values):
    return values.item(0)

sky_age = sky.sort('age', descending=True).select('material','city','name').group(['city', 'material'], first)
sky_age
# Out:
# city      | material        | name first
# Atlanta   | concrete        | Westin Peachtree Plaza
# Atlanta   | mixed/composite | One Atlantic Center
# Atlanta   | steel           | FlatironCity
# Austin    | concrete        | One American Center
# Austin    | steel           | University of Texas Tower
# Baltimore | concrete        | Charles Towers North Apartments
# Baltimore | steel           | Emerson Tower
# Boston    | concrete        | Harbor Towers I
# Boston    | mixed/composite | Ellison Building
# Boston    | steel           | Marriott's Custom House
# ... (81 rows omitted)

# %% [markdown]
# (No peeking! A solution appears below.)

# %%
def first(s):
    "Return the first element in an array."
    return s.item(0)

(sky
 .sort('age', descending=True)
 .pivot('material', 'city', 'name', first)
)#.where('city', 'San Francisco')
# Out:
# city       | concrete                         | mixed/composite                           | steel
# Atlanta    | Westin Peachtree Plaza           | One Atlantic Center                       | FlatironCity
# Austin     | One American Center              |                                           | University of Texas Tower
# Baltimore  | Charles Towers North Apartments  |                                           | Emerson Tower
# Boston     | Harbor Towers I                  | Ellison Building                          | Marriott's Custom House
# Charlotte  | Bank of America Corporate Center | Hearst Tower                              | Midtown Plaza
# Chicago    | The Powhatan                     | American Furniture Mart                   | The Rookery
# Cincinnati | Kroger Building                  | Great American Tower at Queen City Square | PNC Tower
# Cleveland  | National City Center             | 55 Public Square                          | Huntington Bank Building
# ...

# %% [markdown]
# ## Joins ##

# %%
drinks
# Out:
# Drink    | Cafe   | Price
# Milk Tea | Asha   | 5.5
# Espresso | Strada | 1.75
# Latte    | Strada | 3.25
# Espresso | FSM    | 2

# %%
discounts = Table().with_columns(
    'Coupon % off', make_array(10, 25, 5),
    'Location', make_array('Asha', 'Strada', 'Asha')
)
discounts
# Out:
# Coupon % off | Location
# 10           | Asha
# 25           | Strada
# 5            | Asha

# %%
combined = drinks.join('Cafe', discounts, 'Location')
combined
# Out:
# Cafe   | Drink    | Price | Coupon % off
# Asha   | Milk Tea | 5.5   | 10
# Asha   | Milk Tea | 5.5   | 5
# Strada | Espresso | 1.75  | 25
# Strada | Latte    | 3.25  | 25

# %%
discounted_frac = 1 - combined.column('Coupon % off') / 100
combined.with_column(
    'Discounted Price', 
    combined.column('Price') * discounted_frac
)
# Out:
# Cafe   | Drink    | Price | Coupon % off | Discounted Price
# Asha   | Milk Tea | 5.5   | 10           | 4.95
# Asha   | Milk Tea | 5.5   | 5            | 5.225
# Strada | Espresso | 1.75  | 25           | 1.3125
# Strada | Latte    | 3.25  | 25           | 2.4375

# %%
drinks.join('Cafe', drinks, 'Cafe') # same table join with itself
# Out:
# Cafe   | Drink    | Price | Drink_2  | Price_2
# Asha   | Milk Tea | 5.5   | Milk Tea | 5.5
# FSM    | Espresso | 2     | Espresso | 2
# Strada | Espresso | 1.75  | Espresso | 1.75
# Strada | Espresso | 1.75  | Latte    | 3.25
# Strada | Latte    | 3.25  | Espresso | 1.75
# Strada | Latte    | 3.25  | Latte    | 3.25
